# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
data= pd.read_csv('onlinefoods.csv')

# %%
data.head(20)
# Out:
#     Age  Gender Marital Status      Occupation   Monthly Income  \
# 0    20  Female         Single         Student        No Income
# 1    24  Female         Single         Student   Below Rs.10000
# 2    22    Male         Single         Student   Below Rs.10000
# 3    22  Female         Single         Student        No Income
# 4    22    Male         Single         Student   Below Rs.10000
# 5    27  Female        Married        Employee  More than 50000
# 6    22    Male         Single         Student        No Income
# 7    24  Female         Single         Student        No Income
# 8    23  Female         Single         Student        No Income
# 9    23  Female         Single         Student        No Income
# 10   22  Female         Single         Student        No Income
# 11   23    Male         Single         Student   Below Rs.10000
# 12   23    Male         Single         Student        No Income
# 13   21    Male         Single         Student        No Income
# ...

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'Marital Status', 'Occupation', 'Monthly Income',
#        'Educational Qualifications', 'Family size', 'latitude', 'longitude',
#        'Pin code', 'Output', 'Feedback', 'Unnamed: 12'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 388 entries, 0 to 387
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         388 non-null    int64
#  1   Gender                      388 non-null    object
#  2   Marital Status              388 non-null    object
#  3   Occupation                  388 non-null    object
#  4   Monthly Income              388 non-null    object
#  5   Educational Qualifications  388 non-null    object
#  6   Family size                 388 non-null    int64
#  7   latitude                    388 non-null    float64
#  8   longitude                   388 non-null    float64
#  9   Pin code                    388 non-null    int64
#  10  Output                      388 non-null    object
#  11  Feedback                    388 non-null    object
#  12  Unnamed: 12                 388 non-null    object
# ...

# %%
data.shape
# Out:
# (388, 13)

# %%
data.describe()
# Out:
#               Age  Family size    latitude   longitude       Pin code
# count  388.000000   388.000000  388.000000  388.000000     388.000000
# mean    24.628866     3.280928   12.972058   77.600160  560040.113402
# std      2.975593     1.351025    0.044489    0.051354      31.399609
# min     18.000000     1.000000   12.865200   77.484200  560001.000000
# 25%     23.000000     2.000000   12.936900   77.565275  560010.750000
# 50%     24.000000     3.000000   12.977000   77.592100  560033.500000
# 75%     26.000000     4.000000   12.997025   77.630900  560068.000000
# max     33.000000     6.000000   13.102000   77.758200  560109.000000

# %%
data.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Marital Status                0
# Occupation                    0
# Monthly Income                0
# Educational Qualifications    0
# Family size                   0
# latitude                      0
# longitude                     0
# Pin code                      0
# Output                        0
# Feedback                      0
# Unnamed: 12                   0
# dtype: int64

# %% [markdown]
# 1.	What is the distribution of customers' ages in the dataset?

# %%
plt.figure(figsize=(10,5))
plt.hist(data['Age'], bins=20)
plt.title('Distribution of Customers\' Ages')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
print(data['Age'].describe())
# Out:
# count    388.000000
# mean      24.628866
# std        2.975593
# min       18.000000
# 25%       23.000000
# 50%       24.000000
# 75%       26.000000
# max       33.000000
# Name: Age, dtype: float64

# %% [markdown]
# 3.	Generate a heatmap to visualize the distribution of order statuses based on age and gender. This will help you identify any patterns or trends in order status across different demographic groups.

# %%
pivot = data.pivot_table(
    index='Age',
    columns='Gender',
    values= 'longitude',
    aggfunc='mean'
)

plt.figure(figsize=(10, 5))
sns.heatmap(pivot, annot=True, cmap='coolwarm')
plt.title('Order Status Distribution by Age and Gender')
plt.xlabel('Gender')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# 2.	How many male and female customers are there in the dataset?

# %%
data['Gender'].value_counts()
# Out:
# Gender
# Male      222
# Female    166
# Name: count, dtype: int64

# %% [markdown]
# 3.	What are the different marital statuses represented in the dataset, and what is their distribution?

# %%
if 'Marital Status' in data.columns:
    print(data['Marital Status'].value_counts())
else:
    print("The 'Marital Status' column does not exist in the dataset.")
# Out:
# Marital Status
# Single               268
# Married              108
# Prefer not to say     12
# Name: count, dtype: int64

# %%
plt.figure(figsize=(7,3))
plt.pie(data['Marital Status'].value_counts(), labels=data['Marital Status'].value_counts().index, autopct='%1.1f%%')
plt.title('Marital Status Distribution')
plt.show()

# %% [markdown]
# 4.	What are the most common occupations among the customers?

# %%
if 'Occupation' in data.columns:
    print(data['Occupation'].value_counts().head(10))
else:
    print("The 'Occupation' column does not exist in the dataset.")
# Out:
# Occupation
# Student           207
# Employee          118
# Self Employeed     54
# House wife          9
# Name: count, dtype: int64

# %%
plt.figure(figsize=(7,3))
plt.hist(data['Occupation'], bins=30)
plt.title('Occupation Distribution')
plt.xlabel('X-axis Label')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# 5.	How many customers fall into each category of educational qualifications?

# %%
plt.figure(figsize=(10,5))
plt.bar(data['Educational Qualifications'].value_counts().index, data['Educational Qualifications'].value_counts())
plt.title('Educational Qualifications Distribution')
plt.xlabel('Educational Qualifications')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# 6.	What is the average family size of customers?

# %%
if 'Family size' in data.columns:
    average_family_size = data['Family size'].mean()
    print(f'The average family size is: {average_family_size}')
else:
    print("The 'Family size' column does not exist in the dataset.")
# Out:
# The average family size is: 3.2809278350515463

# %% [markdown]
# 7.	What are the most common pin codes among customers?

# %%
if 'Pin code' in data.columns:
    print(data['Pin code'].value_counts().head(10))
else:
    print("The 'Pin code' column does not exist in the dataset.")
# Out:
# Pin code
# 560009    36
# 560038    16
# 560010    14
# 560076    12
# 560095    11
# 560034    11
# 560036     9
# 560075     9
# 560043     8
# 560029     8
# Name: count, dtype: int64

# %%
if 'Pin code' in data.columns:
    N = 10
    top_pin_codes = data['Pin code'].value_counts().head(N)

    plt.figure(figsize=(10, 5))
    plt.bar(top_pin_codes.index.astype(str), top_pin_codes.values,
            color='skyblue')
    plt.title(f'Top {N} Most Common Pin Codes Among Customers')
    plt.xlabel('Pin Codes')
    plt.ylabel('Frequency')
    plt.xticks(rotation=45)
    plt.show()
else:
    print("The 'Pin code' column does not exist in the dataset.")

# %% [markdown]
# 8.	What percentage of customers provided feedback after receiving their orders?

# %%
if 'Feedback' in data.columns:
    feedback_percentage= data['Feedback'].value_counts(normalize=True)
    print(f'Percentage of Customers Provided Feedback: {feedback_percentage[1]*100:.2f}%')
# Out:
# Percentage of Customers Provided Feedback: 18.30%
# C:\Users\sevinj.rahimova\AppData\Local\Temp\ipykernel_19404\2205509445.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(f'Percentage of Customers Provided Feedback: {feedback_percentage[1]*100:.2f}%')

# %%
if 'Feedback' in data.columns:

    total_feedback = data['Feedback'].notnull().sum()
    total_customers = len(data)  # Total number of customers
    percentage_feedback = (total_feedback / total_customers) * 100

    print(f"{percentage_feedback:.2f}% of customers provided feedback after receiving their orders.")
else:
    print("The 'Feedback' column does not exist in the dataset.")
# Out:
# 100.00% of customers provided feedback after receiving their orders.

# %% [markdown]
# 5.	Create a heatmap of the correlation matrix to visualize the correlations between different numerical attributes. This will help you identify any relationships or dependencies between variable.

# %%
numeric_columns = data.select_dtypes(include=['number'])
print(numeric_columns.head())
# Out:
#    Age  Family size  latitude  longitude  Pin code
# 0   20            4   12.9766    77.5993    560001
# 1   24            3   12.9770    77.5773    560009
# 2   22            3   12.9551    77.6593    560017
# 3   22            6   12.9473    77.5616    560019
# 4   22            4   12.9850    77.5533    560010

# %%
correlation_matrix=data[['Age','Family size']].corr()
plt.figure(figsize=(10, 8))  # Set the figure size
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Heatmap of Correlation Matrix')
plt.show()

# %%
correlation_matrix=data[['Age','latitude']].corr()
plt.figure(figsize=(10, 8))  # Set the figure size
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Heatmap of Correlation Matrix')
plt.show()

# %%
correlation_matrix=data[['Age','longitude']].corr()
plt.figure(figsize=(10, 8))  # Set the figure size
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Heatmap of Correlation Matrix')
plt.show()

# %%
correlation_matrix=data[['Family size','latitude']].corr()
plt.figure(figsize=(10, 8))  # Set the figure size
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Heatmap of Correlation Matrix')
plt.show()

# %%
correlation_matrix=data[['Family size','longitude']].corr()
plt.figure(figsize=(10, 8))  # Set the figure size
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Heatmap of Correlation Matrix')
plt.show()

# %%
correlation_matrix = data.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Heatmap of Correlation Matrix')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 correlation_matrix = data.corr()
#       3 plt.figure(figsize=(10, 8))
#       4 sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# ...

# %%
# numerical columns only
numerical_data = data.select_dtypes(include=['number'])
correlation_matrix = numerical_data.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Heatmap of Correlation Matrix')
plt.show()
